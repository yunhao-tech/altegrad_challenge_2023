# %%
import pandas as pd

# %%
df = pd.read_csv('./data/edge_attributes.txt',header=None)

# %%
df.shape
# Out:
# (15213222, 5)

# %%
df
# Out:
#                  0    1    2    3    4
# 0         3.789731  1.0  1.0  0.0  0.0
# 1         5.507777  1.0  0.0  0.0  0.0
# 2         5.029150  1.0  0.0  0.0  0.0
# 3         0.000000  1.0  0.0  0.0  0.0
# 4         5.861668  1.0  0.0  0.0  0.0
# ...            ...  ...  ...  ...  ...
# 15213217  5.638730  1.0  0.0  0.0  0.0
# 15213218  0.000000  1.0  0.0  0.0  0.0
# 15213219  3.813081  1.0  1.0  0.0  0.0
# 15213220  0.000000  1.0  0.0  0.0  0.0
# 15213221  0.000000  1.0  0.0  0.0  0.0
#
# [15213222 rows x 5 columns]

# %%
df.columns
# Out:
# Int64Index([0, 1, 2, 3, 4], dtype='int64')

# %% [markdown]
# edge attributes 1-4 are multi-hot, maybe all zero

# %%
df[df.loc[:,[0]] == ]

# %%
ind = df[df.loc[:,[1,2,3,4]].any(axis=1)].index

# %%
df.index.difference(ind)
# Out:
# Int64Index([   14917,    25765,    25771,    26014,    39813,    41433,
#                50810,    52936,    59972,    62031,
#             ...
#             15190864, 15190902, 15190931, 15205831, 15205838, 15205843,
#             15207055, 15207061, 15207062, 15207623],
#            dtype='int64', length=7269)

# %%
df.loc[df.index.difference(ind)]
# Out:
#                   0    1    2    3    4
# 14917     10.696012  0.0  0.0  0.0  0.0
# 25765     10.999947  0.0  0.0  0.0  0.0
# 25771     11.300112  0.0  0.0  0.0  0.0
# 26014     10.134448  0.0  0.0  0.0  0.0
# 39813     10.045766  0.0  0.0  0.0  0.0
# ...             ...  ...  ...  ...  ...
# 15205843  10.838806  0.0  0.0  0.0  0.0
# 15207055  11.416698  0.0  0.0  0.0  0.0
# 15207061  13.139260  0.0  0.0  0.0  0.0
# 15207062  11.155979  0.0  0.0  0.0  0.0
# 15207623  11.772612  0.0  0.0  0.0  0.0
#
# [7269 rows x 5 columns]

# %%
df = pd.read_csv('./prediction/proteinBert_pretrained_200_dim_automl_log_loss_refit_full.csv', index_col=0, header=0)

# %%
df
# Out:
#         class0    class1    class2    class3    class4    class5    class6  \
# name
# 11as  0.008193  0.003315  0.701645  0.052261  0.002894  0.039056  0.005537
# 16pk  0.000420  0.003584  0.966751  0.000284  0.000123  0.002910  0.007341
# 19hc  0.000650  0.000039  0.002087  0.000304  0.000130  0.001131  0.941220
# 1ag9  0.002638  0.001947  0.690012  0.000735  0.000767  0.009548  0.005794
# 1agx  0.003934  0.005166  0.655500  0.003860  0.004018  0.006262  0.157991
# ...        ...       ...       ...       ...       ...       ...       ...
# 6o81  0.006541  0.006123  0.786758  0.000301  0.002474  0.087389  0.001201
# 6o93  0.014362  0.004080  0.106674  0.007091  0.008953  0.017260  0.039043
# 6ogd  0.001398  0.000601  0.004042  0.000704  0.000597  0.001559  0.004717
# 6okk  0.000551  0.000059  0.004345  0.000047  0.000181  0.001893  0.000257
# 6qmn  0.003447  0.000178  0.000566  0.000340  0.000449  0.001570  0.001566
#
# ...

# %%
df[df<=1/18] = 0

# %%
df.sum(axis=1)
# Out:
# name
# 11as    0.768899
# 16pk    0.966751
# 19hc    0.941220
# 1ag9    0.943810
# 1agx    0.943036
#           ...
# 6o81    0.947850
# 6o93    0.856153
# 6ogd    0.922891
# 6okk    0.984882
# 6qmn    0.985680
# Length: 1223, dtype: float64

# %%
df.divide(df.sum(axis=1), axis=0).to_csv('./prediction/proteinBert_pretrained_200_dim_automl_log_loss_refit_full_postprocessing.csv')
